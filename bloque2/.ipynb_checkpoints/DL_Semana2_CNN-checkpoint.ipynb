# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# # Dataset MNIST

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
x_train = np.expand_dims(x_train, -1)  # [N,28,28,1]
x_test = np.expand_dims(x_test, -1)

# %%
value_counts = Counter(y_train)
print(value_counts)
# Out:
# Counter({1: 6742, 7: 6265, 3: 6131, 2: 5958, 9: 5949, 0: 5923, 6: 5918, 8: 5851, 4: 5842, 5: 5421})

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
i = 15
img = x_train[i]

# %%
plt.imshow(img, cmap="gray")

# %%
y_train[i]
# Out:
# 7

# %% [markdown]
# # Operaciones en una CNN

# %% [markdown]
# ## 1. Convolución
#
# **Qué hace:**
# Proceso donde un *filtro* (o *kernel*) pequeño —por ejemplo de tamaño 3×3— se desliza sobre la imagen y calcula una combinación ponderada (multiplicación y suma) de los píxeles bajo él.
#
# **Ejemplo:**
# Si tienes una imagen de 5×5 píxeles y aplicas un filtro 3×3, en cada posición el filtro toma una pequeña porción (3×3) de la imagen, multiplica cada valor por el peso correspondiente del filtro y suma todos esos valores → ese resultado es **un nuevo píxel** de la imagen salida (el *mapa de características*).
#
# **Intuición:**
# Cada filtro aprende a detectar un patrón visual: bordes, texturas, esquinas, etc.
#
# ---
#
# ## 2. Padding (relleno)
#
# Cuando aplicas una convolución, la imagen se "encoge" (por ejemplo, una imagen 5×5 con filtro 3×3 produce una salida de 3×3).
# **Padding** sirve para *rellenar los bordes* de la imagen con ceros (u otros valores), evitando esa reducción.
#
# **Tipos comunes:**
#
# * `"valid"` → sin padding, la salida se reduce.
# * `"same"` → se añade el padding necesario para que la salida tenga el mismo tamaño que la entrada.
#
# **Intuición:**
# Padding evita perder información de los bordes y mantiene la resolución.
#
# ---
#
# ## 3. Stride (paso)
#
# El **stride** indica *cuánto se mueve el filtro* en cada paso cuando se desliza sobre la imagen.
#
# **Ejemplo:**
#
# * Stride = 1 → el filtro se mueve 1 píxel a la vez (superposición máxima, salida grande).
# * Stride = 2 → se mueve 2 píxeles (menos superposición, salida más pequeña).
#
# **Intuición:**
# Stride controla la *resolución espacial* de la salida. Cuanto mayor el stride, más compresión espacial (y menor coste computacional).
#
# ---
#
# ## 4. Pooling
#
# **Pooling** reduce el tamaño espacial de los mapas de características, conservando la información más importante.
#
# **Tipos comunes:**
#
# * **MaxPooling:** toma el valor máximo dentro de una ventana (ej. 2×2).
# * **AveragePooling:** toma el promedio.
#
# **GlobalMaxPooling:** toma el máximo de *toda* la característica (por canal), reduciendo el mapa completo a un solo valor por canal.
#
# **Intuición:**
# Pooling resume regiones locales → hace la red más robusta a pequeñas traslaciones o distorsiones.
#
# ---
#
# * La convolución detecta patrones.
# * El padding mantiene dimensiones.
# * El stride controla la velocidad de desplazamiento del filtro.
# * El pooling reduce y resume la información.

# %% [markdown]
# # CNN model

# %%
inputs = tf.keras.Input(shape=(28,28,1))
x = tf.keras.layers.Conv2D(8, (3,3), activation="relu")(inputs)
x = tf.keras.layers.MaxPooling2D((2,2))(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(32, activation="relu")(x)
outputs = tf.keras.layers.Dense(10, activation="softmax")(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
# Out:
# I0000 00:00:1764111580.311525  134678 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13683 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:07:00.0, compute capability: 8.9

# %% [markdown]
# # Training

# %%
model.fit(x_train, y_train, epochs=20, batch_size=128, validation_split=0.1)
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764111582.246813  135728 service.cc:152] XLA service 0x7977a0005010 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1764111582.246848  135728 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9
# 2025-11-25 16:59:42.306628: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1764111582.465226  135728 cuda_dnn.cc:529] Loaded cuDNN version 91001
#  46/422 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4011 - loss: 1.8988
# I0000 00:00:1764111584.908407  135728 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7631 - loss: 0.8154 - val_accuracy: 0.9540 - val_loss: 0.1671
# Epoch 2/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9466 - loss: 0.1840 - val_accuracy: 0.9712 - val_loss: 0.1074
# Epoch 3/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9646 - loss: 0.1218 - val_accuracy: 0.9752 - val_loss: 0.0880
# Epoch 4/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9703 - loss: 0.0983 - val_accuracy: 0.9780 - val_loss: 0.0806
# Epoch 5/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9777 - loss: 0.0770 - val_accuracy: 0.9822 - val_loss: 0.0715
# Epoch 6/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9793 - loss: 0.0695 - val_accuracy: 0.9793 - val_loss: 0.0728
# Epoch 7/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9821 - loss: 0.0619 - val_accuracy: 0.9818 - val_loss: 0.0700
# Epoch 8/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9840 - loss: 0.0538 - val_accuracy: 0.9853 - val_loss: 0.0618
# Epoch 9/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9856 - loss: 0.0479 - val_accuracy: 0.9822 - val_loss: 0.0698
# Epoch 10/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9876 - loss: 0.0419 - val_accuracy: 0.9853 - val_loss: 0.0608
# Epoch 11/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9893 - loss: 0.0376 - val_accuracy: 0.9845 - val_loss: 0.0625
# Epoch 12/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9897 - loss: 0.0339 - val_accuracy: 0.9837 - val_loss: 0.0666
# Epoch 13/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9910 - loss: 0.0315 - val_accuracy: 0.9843 - val_loss: 0.0600
# Epoch 14/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9925 - loss: 0.0263 - val_accuracy: 0.9852 - val_loss: 0.0626
# Epoch 15/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9919 - loss: 0.0273 - val_accuracy: 0.9847 - val_loss: 0.0645
# Epoch 16/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9929 - loss: 0.0239 - val_accuracy: 0.9835 - val_loss: 0.0649
# Epoch 17/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9942 - loss: 0.0206 - val_accuracy: 0.9850 - val_loss: 0.0616
# Epoch 18/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0195 - val_accuracy: 0.9840 - val_loss: 0.0643
# Epoch 19/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0198 - val_accuracy: 0.9858 - val_loss: 0.0649
# Epoch 20/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9952 - loss: 0.0170 - val_accuracy: 0.9845 - val_loss: 0.0686

# %%
img = x_test[0:1]
model.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# array([[1.8152494e-07, 2.3452771e-09, 3.7034056e-07, 2.3083944e-06,
#         1.3049725e-09, 2.8882969e-09, 4.5499425e-15, 9.9999690e-01,
#         1.0315064e-07, 2.3015546e-07]], dtype=float32)

# %%
np.argmax(model.predict(img))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 7

# %%
y_test[0]
# Out:
# 7

# %% [markdown]
# # Extraemos filtros de la primera capa

# %%
filters, biases = model.layers[1].get_weights()
print("Forma de los filtros:", filters.shape)
# Out:
# Forma de los filtros: (3, 3, 1, 8)

# %%
filters[:,:, 0, 0]
# Out:
# array([[-0.8452721 ,  0.15194643,  0.55647457],
#        [-1.2112998 ,  0.5047567 ,  0.5072549 ],
#        [-0.9427133 ,  0.04936166,  0.42348647]], dtype=float32)

# %% [markdown]
# # Visualizamos filtros y sus FFT

# %%
plt.figure(figsize=(12,6))
for i in range(filters.shape[-1]):  # cada filtro
    f = filters[:, :, 0, i]

    # Plot filtro
    plt.subplot(2, filters.shape[-1], i+1)
    plt.imshow(f, cmap="gray")
    plt.axis("off")
    plt.title(f"Filtro {i}")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ejemplo de una convolución con una imagen

# %%
img = x_test[0:1]

# %%
first_layer = model.layers[1]

activation_model = tf.keras.Model(inputs=model.input,
                                  outputs=first_layer.output)

activations = activation_model.predict(img)

activations.shape
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# (1, 26, 26, 8)

# %%
activations = activation_model.predict(img)

print("Forma de la activación:", activations.shape)

plt.figure(figsize=(12,6))
for i in range(activations.shape[-1]):
    plt.subplot(2, 4, i+1)
    plt.imshow(activations[0,:,:,i], cmap="gray")
    plt.axis("off")
    plt.title(f"Filtro {i}")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Forma de la activación: (1, 26, 26, 8)

# %%
activations.shape
# Out:
# (1, 26, 26, 8)

# %%
plt.imshow(img[0], cmap="gray")
