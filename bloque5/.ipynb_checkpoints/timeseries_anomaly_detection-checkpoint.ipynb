# %% [markdown]
# # Detección de anomalias usando Autoencoders
#
# Referencia [link](https://keras.io/examples/timeseries/timeseries_anomaly_detection/)

# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers

from matplotlib import pyplot as plt

# %% [markdown]
# ## Datos
#
# Usaremos el conjunto de datos [Numenta Anomaly Benchmark (NAB)](https://www.kaggle.com/boltzmannbrain/nab). Este proporciona series de tiempo artificiales que contienen períodos anómalos de comportamiento etiquetados. Los datos están ordenados, tienen marcas de tiempo y son métricas de un solo valor.
#
# Usaremos el archivo `art_daily_small_noise.csv` para el entrenamiento y el archivo `art_daily_jumpsup.csv` para las pruebas. La simplicidad de este conjunto de datos nos permite demostrar la detección de anomalías de manera efectiva.

# %%
master_url_root = "https://raw.githubusercontent.com/numenta/NAB/master/data/"

df_small_noise_url_suffix = "artificialNoAnomaly/art_daily_small_noise.csv"
df_small_noise_url = master_url_root + df_small_noise_url_suffix
df_small_noise = pd.read_csv(
    df_small_noise_url, parse_dates=True, index_col="timestamp"
)

df_daily_jumpsup_url_suffix = "artificialWithAnomaly/art_daily_jumpsup.csv"
df_daily_jumpsup_url = master_url_root + df_daily_jumpsup_url_suffix
df_daily_jumpsup = pd.read_csv(
    df_daily_jumpsup_url, parse_dates=True, index_col="timestamp"
)

# %%
print(df_small_noise.head())

print(df_daily_jumpsup.head())
# Out:
#                          value
# timestamp
# 2014-04-01 00:00:00  18.324919
# 2014-04-01 00:05:00  21.970327
# 2014-04-01 00:10:00  18.624806
# 2014-04-01 00:15:00  21.953684
# 2014-04-01 00:20:00  21.909120
#                          value
# timestamp
# 2014-04-01 00:00:00  19.761252
# 2014-04-01 00:05:00  20.500833
# 2014-04-01 00:10:00  19.961641
# 2014-04-01 00:15:00  21.490266
# 2014-04-01 00:20:00  20.187739

# %% [markdown]
# ## Visualización de los datos
# ### Series sin anomalías

# %%
fig, ax = plt.subplots()
df_small_noise.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# ### Series con anomalías

# %%
fig, ax = plt.subplots()
df_daily_jumpsup.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# ## Preprocesado
#
# Obtenemos los valores del archivo de datos de la serie de tiempo de entrenamiento y normalizamos los datos de `value`. Tenemos un `value` cada 5 minutos durante 14 días.
#
# * 24 * 60 / 5 = **288 pasos de tiempo por día**
# * 288 * 14 = **4032 puntos de datos** en total"

# %%
training_mean = df_small_noise.mean()
training_std = df_small_noise.std()
df_training_value = (df_small_noise - training_mean) / training_std
print("Número de ejemplos de entrenamiento:", len(df_training_value))
# Out:
# Número de ejemplos de entrenamiento: 4032

# %% [markdown]
# ### Creación de secuancias

# %%
TIME_STEPS = 288


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)
# Out:
# Training input shape:  (3745, 288, 1)

# %% [markdown]
# ## Construcción del modelo

# %%
model = tf.keras.Sequential(
    [
        layers.Input(shape=(x_train.shape[1], x_train.shape[2])),
        layers.Conv1D(
            filters=32,
            kernel_size=7,
            padding="same",
            strides=2,
            activation="relu",
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1D(
            filters=16,
            kernel_size=7,
            padding="same",
            strides=2,
            activation="relu",
        ),
        layers.Conv1DTranspose(
            filters=16,
            kernel_size=7,
            padding="same",
            strides=2,
            activation="relu",
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1DTranspose(
            filters=32,
            kernel_size=7,
            padding="same",
            strides=2,
            activation="relu",
        ),
        layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
    ]
)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 144, 32)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 144, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 72, 16)         │         3,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_3              │ (None, 144, 16)        │         1,808 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 144, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_4              │ (None, 288, 32)        │         3,616 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_5              │ (None, 288, 1)         │           225 │
# │ (Conv1DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,505 (37.13 KB)
#  Trainable params: 9,505 (37.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Entrenamiento

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=50,
    batch_size=128,
    validation_split=0.1,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")
    ],
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764606754.112236  219911 service.cc:152] XLA service 0x70e04c008ca0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1764606754.112268  219911 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9
# 2025-12-01 10:32:34.169487: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1764606754.383187  219911 cuda_dnn.cc:529] Loaded cuDNN version 91001
# 21/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8507
# I0000 00:00:1764606757.301144  219911 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 106ms/step - loss: 0.7737 - val_loss: 0.0613
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0853 - val_loss: 0.0426
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0604 - val_loss: 0.0371
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0512 - val_loss: 0.0304
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0440 - val_loss: 0.0268
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0389 - val_loss: 0.0239
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0350 - val_loss: 0.0215
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0317 - val_loss: 0.0201
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0289 - val_loss: 0.0186
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0267 - val_loss: 0.0200
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0250 - val_loss: 0.0190
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0236 - val_loss: 0.0189
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0224 - val_loss: 0.0195
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0213 - val_loss: 0.0183
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0204 - val_loss: 0.0170
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0194 - val_loss: 0.0180
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0189 - val_loss: 0.0182
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - val_loss: 0.0177
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0173 - val_loss: 0.0164
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166 - val_loss: 0.0161
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0158 - val_loss: 0.0157
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0151 - val_loss: 0.0136
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - val_loss: 0.0130
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0137 - val_loss: 0.0124
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131 - val_loss: 0.0125
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126 - val_loss: 0.0105
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - val_loss: 0.0113
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - val_loss: 0.0110
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0113 - val_loss: 0.0099
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0110 - val_loss: 0.0102
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0107 - val_loss: 0.0105
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0104 - val_loss: 0.0094
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0101 - val_loss: 0.0088
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097 - val_loss: 0.0082
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0095 - val_loss: 0.0084
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - val_loss: 0.0082
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0091 - val_loss: 0.0070
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - val_loss: 0.0072
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0086 - val_loss: 0.0072
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - val_loss: 0.0063
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0082 - val_loss: 0.0065
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - val_loss: 0.0066
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - val_loss: 0.0063
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0076 - val_loss: 0.0062
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - val_loss: 0.0055
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - val_loss: 0.0055
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069 - val_loss: 0.0058
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0058
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0058

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Detectando anomalías
#
# Detectaremos anomalías determinando qué tan bien nuestro modelo puede reconstruir los datos de entrada.
#
# 1. Calcular la pérdida MAE en las muestras de entrenamiento.
# 2. Encontrar el valor máximo de la pérdida MAE. Este es el peor desempeño de nuestro modelo al intentar reconstruir una muestra. Usaremos este valor como el `umbral` para la detección de anomalías.
# 3. Si la pérdida de reconstrucción para una muestra es mayor que este valor `umbral`, entonces podemos inferir que el modelo está observando un patrón con el que no está familiarizado. Etiquetaremos esta muestra como una `anomalía`.

# %%
# Obtenemos el MAE.
x_train_pred = model.predict(x_train)
train_mae_loss = np.mean(np.abs(x_train_pred - x_train), axis=1)

plt.hist(train_mae_loss, bins=50)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

threshold = np.max(train_mae_loss)
print("Reconstrucción del umbral de error: ", threshold)
# Out:
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Reconstrucción del umbral de error:  0.07248152541987246

# %% [markdown]
# ### Comparar reconstrucción
#
# Veamos cómo nuestro modelo ha reconstruido la primera muestra.
# Esta corresponde a los **288 pasos de tiempo del día 1** de nuestro conjunto de entrenamiento.

# %%
# Checking how the first sequence is learnt
plt.plot(x_train[0])
plt.plot(x_train_pred[0])
plt.show()

# %% [markdown]
# ### Preparación de los datos test

# %%
df_test_value = (df_daily_jumpsup - training_mean) / training_std
fig, ax = plt.subplots()
df_test_value.plot(legend=False, ax=ax)
plt.show()

x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Test input shape:  (3745, 288, 1)

# %%
x_test_pred = model.predict(x_test)
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
test_mae_loss = test_mae_loss.reshape((-1))

plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

# Detect all the samples which are anomalies.
anomalies = test_mae_loss > threshold
print("Number of anomaly samples: ", np.sum(anomalies))
print("Indices of anomaly samples: ", np.where(anomalies))
# Out:
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Number of anomaly samples:  401
# Indices of anomaly samples:  (array([ 793,  794, 1945, 1946, 2521, 2522, 2701, 2702, 2703, 2704, 2705,
#        2706, 2707, 2708, 2709, 2710, 2711, 2712, 2713, 2714, 2715, 2716,
#        2717, 2718, 2719, 2720, 2721, 2722, 2723, 2724, 2725, 2726, 2727,
#        2728, 2729, 2730, 2731, 2732, 2733, 2734, 2735, 2736, 2737, 2738,
#        2739, 2740, 2741, 2742, 2743, 2744, 2745, 2746, 2747, 2748, 2749,
#        2750, 2751, 2752, 2753, 2754, 2755, 2756, 2757, 2758, 2759, 2760,
#        2761, 2762, 2763, 2764, 2765, 2766, 2767, 2768, 2769, 2770, 2771,
#        2772, 2773, 2774, 2775, 2776, 2777, 2778, 2779, 2780, 2781, 2782,
#        2783, 2784, 2785, 2786, 2787, 2788, 2789, 2790, 2791, 2792, 2793,
#        2794, 2795, 2796, 2797, 2798, 2799, 2800, 2801, 2802, 2803, 2804,
#        2805, 2806, 2807, 2808, 2809, 2810, 2811, 2812, 2813, 2814, 2815,
#        2816, 2817, 2818, 2819, 2820, 2821, 2822, 2823, 2824, 2825, 2826,
#        2827, 2828, 2829, 2830, 2831, 2832, 2833, 2834, 2835, 2836, 2837,
#        2838, 2839, 2840, 2841, 2842, 2843, 2844, 2845, 2846, 2847, 2848,
#        2849, 2850, 2851, 2852, 2853, 2854, 2855, 2856, 2857, 2858, 2859,
#        2860, 2861, 2862, 2863, 2864, 2865, 2866, 2867, 2868, 2869, 2870,
#        2871, 2872, 2873, 2874, 2875, 2876, 2877, 2878, 2879, 2880, 2881,
#        2882, 2883, 2884, 2885, 2886, 2887, 2888, 2889, 2890, 2891, 2892,
#        2893, 2894, 2895, 2896, 2897, 2898, 2899, 2900, 2901, 2902, 2903,
#        2904, 2905, 2906, 2907, 2908, 2909, 2910, 2911, 2912, 2913, 2914,
#        2915, 2916, 2917, 2918, 2919, 2920, 2921, 2922, 2923, 2924, 2925,
#        2926, 2927, 2928, 2929, 2930, 2931, 2932, 2933, 2934, 2935, 2936,
#        2937, 2938, 2939, 2940, 2941, 2942, 2943, 2944, 2945, 2946, 2947,
#        2948, 2949, 2950, 2951, 2952, 2953, 2954, 2955, 2956, 2957, 2958,
#        2959, 2960, 2961, 2962, 2963, 2964, 2965, 2966, 2967, 2968, 2969,
#        2970, 2971, 2972, 2973, 2974, 2975, 2976, 2977, 2978, 2979, 2980,
#        2981, 2982, 2983, 2984, 2985, 2986, 2987, 2988, 2989, 2990, 2991,
#        2992, 2993, 2994, 2995, 2996, 2997, 2998, 2999, 3000, 3001, 3002,
#        3003, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3011, 3012, 3013,
#        3014, 3015, 3016, 3017, 3018, 3019, 3020, 3021, 3022, 3023, 3024,
#        3025, 3026, 3027, 3028, 3029, 3030, 3031, 3032, 3033, 3034, 3035,
#        3036, 3037, 3038, 3039, 3040, 3041, 3042, 3043, 3044, 3045, 3046,
#        3047, 3048, 3049, 3050, 3051, 3052, 3053, 3054, 3055, 3056, 3057,
#        3058, 3059, 3060, 3061, 3062, 3063, 3064, 3065, 3066, 3067, 3068,
#        3069, 3070, 3071, 3072, 3073, 3074, 3075, 3076, 3077, 3078, 3079,
#        3080, 3081, 3082, 3083, 3084, 3085, 3086, 3087, 3088, 3089, 3090,
#        3091, 3092, 3093, 3094, 3095]),)

# %% [markdown]
# ## Plot de anomalías
#
# Ahora ya conocemos las muestras de los datos que son anomalías. Con esto, encontraremos las `timestamps` correspondientes a partir de los datos originales de prueba. Usaremos el siguiente método para hacerlo:
#
# Supongamos que **time_steps = 3** y tenemos **10 valores de entrenamiento**. Nuestro `x_train` se verá así:
#
# * 0, 1, 2
# * 1, 2, 3
# * 2, 3, 4
# * 3, 4, 5
# * 4, 5, 6
# * 5, 6, 7
# * 6, 7, 8
# * 7, 8, 9
#
# Excepto los valores iniciales y finales (time_steps - 1), todos los demás aparecerán en `time_steps` muestras distintas. Por lo tanto, si sabemos que las muestras
# [(3, 4, 5), (4, 5, 6), (5, 6, 7)]
# son anomalías, podemos decir que el punto de dato **5** es una anomalía.

# %%
anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)

# %%
df_subset = df_daily_jumpsup.iloc[anomalous_data_indices]
fig, ax = plt.subplots()
df_daily_jumpsup.plot(legend=False, ax=ax)
df_subset.plot(legend=False, ax=ax, color="r")
plt.show()
